# %% [markdown]
# ## Task
#
# 1. Define a 1D autonomous ODE $\dot{x} = f(x)$.
# 2. Find the equilibrium points ($f(x^*) = 0$).
# 3. Sketch the Phase Line to determine stability (Source vs. Sink).
# 4. Confirm via `scipy` time-series simulations starting near the points.
