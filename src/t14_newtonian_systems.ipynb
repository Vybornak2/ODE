# %% [markdown]
# ## Task
#
# 1. Pick a 1-degree-of-freedom mechanical system with a potential $V(x)$.
# 2. Write the equation $\ddot{x} = -V'(x)$.
# 3. Convert it to a first-order system ($v = \dot{x}$).
# 4. Analyze the fixed points and sketch the energy level curves $E = \frac{1}{2}v^2 + V(x)$.
