# %% [markdown]
# ## Task
#
# 1. Use the system from the Linearization task.
# 2. Generate phase portraits zoomed in around the fixed points.
# 3. Overlay the eigenvectors of the linearized system.
# 4. Observe how well the linear approximation matches the nonlinear flow locally.
