# %% [markdown]
# ## Task
#
# 1. Select a physical system: an Electrical RC circuit or a Chemical Mixing tank.
# 2. Derive the system's differential equation from physical laws (Kirchhoff's or Mass Balance).
# 3. Simulate the system response to a step input (e.g., switch closing or adding solute).
# 4. Plot voltage vs. time or concentration vs. time.
