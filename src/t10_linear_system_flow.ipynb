# %% [markdown]
# ## Task
#
# 1. Define a 2D Linear System.
# 2. Create a grid of points $(x, y)$ using `numpy`.
# 3. Calculate the velocity vector $(\dot{x}, \dot{y})$ at each point.
# 4. Use `plt.quiver` or `plt.streamplot` to visualize the flow field of the system.
