# %% [markdown]
# ## Task
#
# 1. Define a system depending on a parameter $\mu$ (e.g., Saddle-Node or Hopf bifurcation).
# 2. For a range of $\mu$, find the fixed points and their stability.
# 3. Plot the Bifurcation Diagram (Fixed points $x^*$ vs. Parameter $\mu$).
# 4. Visualize how the phase portrait changes as $\mu$ crosses the critical value.
