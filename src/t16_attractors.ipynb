# %% [markdown]
# ## Task
#
# 1. Define the Lorenz system (or Rössler attractor).
# 2. Integrate the system for a long duration.
# 3. Use a 3D plot to visualize the Butterfly effect (Strange Attractor).
# 4. Show sensitivity to initial conditions by plotting two close trajectories.
