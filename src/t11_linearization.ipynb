# %% [markdown]
# ## Task
#
# 1. Define a nonlinear system (e.g., Simple Pendulum or Duffing Oscillator).
# 2. Find fixed points by setting derivatives to zero.
# 3. Compute the Jacobian matrix $J$ at these points using `sympy`.
# 4. Analyze eigenvalues of $J$ to determine local stability.
