# %% [markdown]
# ## Task
#
# 1. Implement the Van der Pol oscillator equation.
# 2. Vary the damping parameter $\mu$.
# 3. Observe the change in the limit cycle shape (Circle vs. Relaxation Oscillation).
# 4. Discuss the existence of the limit cycle using Lienard's Theorem (theoretical) but verify numerically.
