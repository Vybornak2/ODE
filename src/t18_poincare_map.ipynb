# %% [markdown]
# ## Task
#
# 1. Define a lower-dimensional cross-section $\Sigma$ transversal to the flow.
# 2. Compute the first return map $P: \Sigma \to \Sigma$ numerically.
# 3. Plot the sequence of points $x_{n+1} = P(x_n)$ (Cobweb plot or scatter).
# 4. Analyze the fixed point of the map to determine orbit stability.
