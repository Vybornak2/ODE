# %% [markdown]
# ## Task
#
# 1. Define a system known to have a periodic orbit (e.g., undamped harmonic oscillator or Lotka-Volterra).
# 2. Determine the period of the cycle.
# 3. Investigate the stability of the cycle (is it a limit cycle or a center?).
# 4. Plot the time series to verify periodicity.
