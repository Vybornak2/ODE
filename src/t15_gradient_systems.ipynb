# %% [markdown]
# ## Task
#
# 1. Define a potential function $V(x, y)$.
# 2. Formulate the gradient system $\dot{\mathbf{x}} = -\nabla V(\mathbf{x})$.
# 3. Show theoretically that there are no periodic orbits (Lyapunov function argument).
# 4. Plot the contours of $V$ and the orthogonal trajectories of the flow.
